# %% [markdown]
# # Analytics by AI

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
import matplotlib.pyplot as plt
from utils import load_analytics_dataset, show_3_distribution_charts, show_3_sns_charts
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Price Data

# %%
# %%time
dataset = load_analytics_dataset()
# Out:
# CPU times: user 1min 33s, sys: 341 ms, total: 1min 33s
# Wall time: 1min 35s

# %%
# data = dataset[dataset.index > '2020-11-01 00:00:00'].copy()
data = dataset.copy()

# %%
data.columns
