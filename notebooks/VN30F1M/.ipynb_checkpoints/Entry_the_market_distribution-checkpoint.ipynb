# %% [markdown]
# # Entry the market distribution - Analytics

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
from utils import load_analytics_dataset, show_3_distribution_charts, show_3_sns_charts

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 120
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load Price Data

# %%
# %%time
dataset = load_analytics_dataset()
# Out:
# CPU times: user 1.3 s, sys: 78 ms, total: 1.38 s
# Wall time: 1.48 s

# %%
# data = dataset[dataset.index > '2020-11-01 00:00:00'].copy()
data = dataset.copy()

# %%
data
# Out:
#                        Open    High     Low   Close  Volume  hour  minute  \
# Date
# 2018-08-20 09:05:00   945.8   946.1   945.5   946.1     877     9       5
# 2018-08-20 09:10:00   945.9   946.2   945.7   945.9     604     9      10
# 2018-08-20 09:15:00   946.0   946.5   946.0   946.1     797     9      15
# 2018-08-20 09:20:00   946.0   947.1   946.0   946.8    1195     9      20
# 2018-08-20 09:25:00   946.6   947.0   946.1   946.7     915     9      25
# ...                     ...     ...     ...     ...     ...   ...     ...
# 2025-11-04 14:10:00  1890.7  1891.0  1885.5  1887.3    5379    14      10
# 2025-11-04 14:15:00  1887.2  1899.0  1887.2  1898.5   13871    14      15
# 2025-11-04 14:20:00  1898.2  1907.7  1897.0  1904.2   16090    14      20
# 2025-11-04 14:25:00  1904.1  1907.4  1900.3  1902.7    9901    14      25
# 2025-11-04 14:45:00  1898.0  1898.0  1898.0  1898.0    6043    14      45
#
#                      day_of_month  month  year  ...  short_mae  long_mfe  \
# Date                                            ...
# 2018-08-20 09:05:00            20      8  2018  ...   0.570764  0.570764
# 2018-08-20 09:10:00            20      8  2018  ...   0.592029  0.592029
# 2018-08-20 09:15:00            20      8  2018  ...   0.570764  0.570764
# 2018-08-20 09:20:00            20      8  2018  ...   0.496409  0.496409
# 2018-08-20 09:25:00            20      8  2018  ...   0.507024  0.507024
# ...                           ...    ...   ...  ...        ...       ...
# 2025-11-04 14:10:00             4     11  2025  ...   1.080909  1.080909
# 2025-11-04 14:15:00             4     11  2025  ...   0.484593  0.484593
# 2025-11-04 14:20:00             4     11  2025  ...   0.168050  0.168050
# 2025-11-04 14:25:00             4     11  2025  ...        NaN       NaN
# 2025-11-04 14:45:00             4     11  2025  ...        NaN       NaN
#
#                      short_mfe     rr_long  rr_short  eod_return_long  \
# Date
# 2018-08-20 09:05:00   0.369940    1.542857  0.648148        -0.147976
# 2018-08-20 09:10:00   0.348874    1.696970  0.589286        -0.126863
# 2018-08-20 09:15:00   0.369940    1.542857  0.648148        -0.147976
# 2018-08-20 09:20:00   0.443599    1.119048  0.893617        -0.221800
# 2018-08-20 09:25:00   0.433083    1.170732  0.854167        -0.211260
# ...                        ...         ...       ...              ...
# 2025-11-04 14:10:00   0.005299  204.000000  0.004902         0.815981
# 2025-11-04 14:15:00   0.079010    6.133333  0.163043         0.221227
# 2025-11-04 14:20:00   0.204810    0.820513  1.218750        -0.078773
# 2025-11-04 14:25:00        NaN         NaN       NaN              NaN
# 2025-11-04 14:45:00        NaN         NaN       NaN              NaN
#
#                      eod_return_short  price_range  intraday_position  \
# Date
# 2018-08-20 09:05:00          0.147976          8.9               norm
# 2018-08-20 09:10:00          0.126863          8.9               norm
# 2018-08-20 09:15:00          0.147976          8.9               norm
# 2018-08-20 09:20:00          0.221800          8.9               norm
# 2018-08-20 09:25:00          0.211260          8.9               norm
# ...                               ...          ...                ...
# 2025-11-04 14:10:00         -0.815981         56.7               norm
# 2025-11-04 14:15:00         -0.221227         56.7               norm
# 2025-11-04 14:20:00          0.078773         56.7               peak
# 2025-11-04 14:25:00               NaN         56.7               norm
# 2025-11-04 14:45:00               NaN         56.7               norm
#
#                      price_shape
# Date
# 2018-08-20 09:05:00   bear_grind
# 2018-08-20 09:10:00   bear_grind
# 2018-08-20 09:15:00   bear_grind
# 2018-08-20 09:20:00   bear_grind
# 2018-08-20 09:25:00   bear_grind
# ...                          ...
# 2025-11-04 14:10:00  strong_bull
# 2025-11-04 14:15:00  strong_bull
# 2025-11-04 14:20:00  strong_bull
# 2025-11-04 14:25:00  strong_bull
# 2025-11-04 14:45:00  strong_bull
#
# [88026 rows x 113 columns]

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'hour', 'minute',
#        'day_of_month', 'month', 'year',
#        ...
#        'short_mae', 'long_mfe', 'short_mfe', 'rr_long', 'rr_short',
#        'eod_return_long', 'eod_return_short', 'price_range',
#        'intraday_position', 'price_shape'],
#       dtype='str', length=113)

# %%
data['allow_entry'] = data['allow_entry'].fillna('NaN')

# %%
show_3_distribution_charts(data['lower_wick_group'], data['allow_entry'])

# %% [markdown]
# ## Tỉ lệ % có thể vào lệnh

# %%
total_time = len(data)
tradable_time = len(data[(data.allow_entry=='Yes - Buy') | (data.allow_entry=='Yes - Sell')])
non_tradable_time = total_time - tradable_time

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# 1. Pie chart (tỷ lệ)
axes[0].pie(
    [tradable_time, non_tradable_time],
    labels=['Tradable', 'Non-Tradable'],
    autopct='%1.1f%%'
)
axes[0].set_title('Tradable Opportunity Ratio')

# 2. Bar chart (số lượng)
axes[1].bar(
    ['Total', 'Tradable'],
    [total_time, tradable_time]
)
axes[1].set_title('Count Comparison')
axes[1].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Analytics

# %%
from scipy.stats import chi2_contingency

# %%
ct = pd.crosstab(data['hour'], data['allow_entry'])
chi2, p, _, _ = chi2_contingency(ct)
print(p)
# Out:
# 0.0

# %%
data.ema_cross_signal.unique()
# Out:
# <StringArray>
# [nan, 'Buy', 'Sell']
# Length: 3, dtype: str

# %%
show_3_sns_charts(data, 'wick_imbalance', 'allow_entry')

# %%
show_3_sns_charts(data, 'adx', 'allow_entry')

# %%
show_3_sns_charts(data, 'atr', 'allow_entry')

# %%
dfx = data[data.ema_cross_signal.notna()]

# %%
show_3_distribution_chart(dfx['ema_cross_signal'], dfx['allow_entry'])

# %% [markdown]
# ### 3. MQH giữa màu sắc nến và Allow Entry

# %%
show_3_distribution_chart(data['color'], data['allow_entry'])

# %% [markdown]
# ## 2. MQH giữa RSI và Allow Entry

# %%
show_3_sns_charts(data, 'rsi', 'allow_entry')

# %% [markdown]
# ## 1. MQH giữa Hour và Allow Entry

# %%
show_3_distribution_chart(data['hour'], data['allow_entry'])
